# %% [markdown]
# paguinas de alquileres

# %% [markdown]
# https://www.argenprop.com/departamentos/alquiler/corrientes-cor-o-resistencia
#
#
# https://www.icasas.com.ar/alquiler/casas,departamentos/corrientes/corrientes
#
#
# https://www.buscainmueble.com/departamentos/alquiler/corrientes
#
#
# https://www.remax.com.ar/listings/rent?page=0&pageSize=24&sort=-createdAt&in:operationId=2&in:eStageId=0,1,2,3,4&in:typeId=9,10,11,1,2,3,4,5,6,7,8,12&locations=in:::220@Capital#%20%3Cb%3ECorrie%3C/b%3Entes::::&filterCount=1&viewMode=listViewMode
#
#
# https://www.sotosinmobiliaria.com.ar/Buscar?operation=2&ptypes=2&o=2,2&1=1
#
#
# https://www.cohenycohen.com.ar/properties/operation/forRent
#
#
# https://www.mahlerpropiedades.com.ar/alquiler

# %%
#librerias 
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
import time

# %% [markdown]
# 1

# %% [markdown]
# argenprop alquileres

# %%
# Abrir el navegador Edge
driver = webdriver.Edge()

links=[]

try:
    # Página web
    url = 'https://www.argenprop.com/departamentos/alquiler/corrientes-o-corrientes-arg'

    # Abrir la página
    driver.get(url)

    # Obtener el elemento entre pagination__separator y pagination__page-next
    try:
        elemento = driver.find_element(By.XPATH, '//li[@class="pagination__separator"]/following-sibling::li[1][not(contains(@class, "pagination__page-next"))]')

    # Convertir el texto del elemento a un número entero
        numero_paginas = int(elemento.text)
    except NoSuchElementException:
        print("No se encontró el elemento con el número de páginas")
        numero_paginas = 1    
    

    for i in range(1, numero_paginas + 1):
        print(f"Página {i}")
        
        # Obtener el div que contiene los departamentos
        try:
            departamentos_div = driver.find_element(By.XPATH, '//div[@class="listing__items"]')
        except NoSuchElementException:
            print("No se encontró el div que contiene los departamentos")
            continue
        
        # Obtener los departamentos usando un XPath relativo
        departamentos = departamentos_div.find_elements(By.XPATH, './div')
        print(f"Número de departamentos: {len(departamentos)}")
        
        for f in range(len(departamentos)):
            print(f"Departamento {f+1}")
            try:
                enlaces = departamentos[f].find_elements(By.XPATH, './/a')
                for enlace in enlaces:
                    href = enlace.get_attribute('href')
                    print(f"Href: {href}")
                    links.append(href)
            except NoSuchElementException:
                print(f"No se encontró el enlace en el departamento {f+1}")
        
        # Cambiar de página
        if i < numero_paginas:
            try:
                siguiente = driver.find_element(By.XPATH, '//li[@class="pagination__page-next pagination__page"]/a')
                siguiente_href = siguiente.get_attribute('href')
                driver.get(siguiente_href)
                time.sleep(3)  # Esperar un momento para que la página cargue
            except NoSuchElementException:
                print("No se encontró el botón de siguiente página")
                break
finally:
    # Cerrar el navegador
    # driver.quit()
    print("Fin del programa")
# Out:
# No se encontró el elemento con el número de páginas
# Página 1
# Número de departamentos: 10
# Departamento 1
# Href: https://www.argenprop.com/departamento-en-alquiler-en-corrientes-2-ambientes--16399660
# Departamento 2
# Href: https://www.argenprop.com/departamento-en-alquiler-en-corrientes-2-ambientes--15985363
# Departamento 3
# Departamento 4
# Href: https://www.argenprop.com/departamento-en-alquiler-en-corrientes-1-ambiente--12863411
# Departamento 5
# Href: https://www.argenprop.com/departamento-en-alquiler-en-corrientes-1-ambiente--16107074
# Departamento 6
# Href: https://www.argenprop.com/departamento-en-alquiler-en-corrientes-3-ambientes--16206263
# Departamento 7
# Href: https://www.argenprop.com/departamento-en-alquiler-en-corrientes-2-ambientes--15951326
# Departamento 8
# Departamento 9
# Href: https://www.argenprop.com/departamento-en-alquiler-en-corrientes-2-ambientes--16259776
# Departamento 10
# Href: https://www.argenprop.com/departamento-en-alquiler-en-corrientes-2-ambientes--16331405
# Fin del programa

# %%
# iterar sobre los enlaces guardados en la lista links
data_argenprop = []


driver = webdriver.Edge()
try:
    for enlace in links:

        driver.get(enlace)
        time.sleep(3)  # Esperar un momento para que la página cargue
        
        # Obtener la información del departamento
        try:
            address = driver.find_element(By.XPATH, '//h2[@class="titlebar__address"]').text
        except NoSuchElementException:
            print("No se encontró la direccion")
            address = None
        
        try:
            price = driver.find_element(By.XPATH, '//p[@class="titlebar__price"]').text
        except NoSuchElementException:
            print("No se encontró el precio")
            price = None
        
        
        #div de descripcion
        try:
            expensas = driver.find_element(By.XPATH, '//p[@class="titlebar__expenses hide-in-mobile"]').text
        except NoSuchElementException:
            print("No se encontró el precio de las expensas")
            expensas = None
        
        try:
            descripcion = driver.find_element(By.XPATH, '//div[@class="property-description"]/ul[@class="property-main-features"]')
        except NoSuchElementException:
            print("No se encontró la descripción")
            descripcion = None
            
            
        try:
            tipo = descripcion.find_element(By.XPATH, './li[1]').text
        except NoSuchElementException:
            print("No se encontró el tipo")
            tipo = None
            
        try:
            superficie = descripcion.find_element(By.XPATH, './li[@title="Sup. cubierta"]').text
        except NoSuchElementException:
            print("No se encontró la superficie")
            superficie = None
            
        try:
            cantidad_ambientes = descripcion.find_element(By.XPATH, './li[@title="Ambientes"]').text
        except NoSuchElementException:
            print("No se encontró la cantidad de ambientes")
            cantidad_ambientes = None
            
        try:
            cantidad_dormitorios = descripcion.find_element(By.XPATH, './li[@title="Dormitorios"]').text
        except NoSuchElementException:
            print("No se encontró la cantidad de dormitorios")
            cantidad_dormitorios = None
            
        try:
            cantidad_banos = descripcion.find_element(By.XPATH, './li[@title="Baños"]').text
        except NoSuchElementException:
            print("No se encontró la cantidad de baños")
            cantidad_banos = None
            
        try:
            # obtener div de mapa de google map
            mapa = driver.find_element(By.XPATH, '//div[@class="leaflet-container leaflet-fade-anim leaflet-grab leaflet-touch-drag"]')
        except NoSuchElementException:
            print("No se encontró el mapa")
            
        
        #obtener latitud y longitud de los atributos del div
        try:
            latitud = mapa.get_attribute('data-latitude')
        except NoSuchElementException:
            print("No se encontró la latitud")
            latitud = None
            
        try:
            longitud = mapa.get_attribute('data-longitude')
        except NoSuchElementException:
            print("No se encontró la longitud")
            longitud = None
            
        departamento_info = {
            "enlace": enlace,
            "address": address,
            "price": price,
            "expensas": expensas,
            "tipo": tipo,
            "superficie": superficie,
            "cantidad_ambientes": cantidad_ambientes,
            "cantidad_dormitorios": cantidad_dormitorios,
            "cantidad_banos": cantidad_banos,
            "latitud": latitud,
            "longitud": longitud
        }
        
        print(departamento_info)     
        
        data_argenprop.append(departamento_info)   



finally:
    driver.quit()
# Out:
# No se encontró el precio de las expensas
# No se encontró la superficie
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-corrientes-2-ambientes--16399660', 'address': 'Córdoba 400', 'price': '$ 450.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,4623', 'longitud': '-58,83374'}
# No se encontró el precio de las expensas
# No se encontró la superficie
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-corrientes-2-ambientes--15985363', 'address': 'Pje Tabares 700', 'price': '$ 150.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,46819', 'longitud': '-58,78667'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de dormitorios
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-corrientes-1-ambiente--12863411', 'address': 'FRAY JOSE DE LA QUINTANA 1700', 'price': '$ 45.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '25 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': None, 'latitud': '-27,46389', 'longitud': '-58,82811'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de dormitorios
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-corrientes-1-ambiente--16107074', 'address': 'San Martín 2300', 'price': '$ 140.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '18 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': None, 'latitud': '-27,47146', 'longitud': '-58,82133'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-corrientes-3-ambientes--16206263', 'address': 'BUENOS AIRES 1000', 'price': '$ 600.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '80 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,468393', 'longitud': '-58,840446'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-corrientes-2-ambientes--15951326', 'address': 'ALBERDI 1800', 'price': '$ 250.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '30 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': None, 'latitud': '-27,477886', 'longitud': '-58,84448'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-corrientes-2-ambientes--16259776', 'address': 'SEGOVIA LISANDRO 1800', 'price': '$ 320.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '35 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,478836', 'longitud': '-58,83532'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-corrientes-2-ambientes--16331405', 'address': 'Avenida Maipú 2900', 'price': '$ 340.000', 'expensas': '+ $100.000 expensas', 'tipo': 'Departamento', 'superficie': '46 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,50135', 'longitud': '-58,813183'}

# %%
#lista a data frame
df_argenpro = pd.DataFrame(data_argenprop)
df_argenpro.to_csv('departamentos_argenprop.csv', index=False)

# %% [markdown]
# segunda paguina web

# %%
#librerias 
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
import time

# %%
import re
def extraer_latitud_longitud(url):
    # Expresión regular para capturar la latitud y longitud
    patron = r"!3d(-?\d+\.\d+)!4d(-?\d+\.\d+)"
    coincidencia = re.search(patron, url)
    
    if coincidencia:
        latitud = float(coincidencia.group(1))
        longitud = float(coincidencia.group(2))
        return latitud, longitud
    else:
        return None

# %%
# Abrir el navegador Edge
driver = webdriver.Edge()

links=[]

try:
    # Página web
    url = 'https://www.zonaprop.com.ar/departamentos-alquiler-corrientes-cr.html'

    # Abrir la página
    driver.get(url)
    
    wait = WebDriverWait(driver, 10)

    # Obtener el elemento entre pagination__separator y pagination__page-next
    try:
        texto_con_cantidad = driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/div/div/div[2]/div[2]/div[1]/div/div[1]/h1').text
    except NoSuchElementException:
        print("No se encontró el texto con la cantidad de departamentos")
    # extraer el texto con la cantidad de departamentos dejando solo los numeros
    numero_despartamentos = int(''.join(filter(str.isdigit, texto_con_cantidad)))

    numero_paginas = int(np.ceil(numero_despartamentos / 30))

    print(f"Numero de paginas: {numero_paginas}")



    for i in range(1, numero_paginas + 1):
        print(f"Página {i}")
        
        # Obtener el div que contiene los departamentos
        try:
            departamentos_div = driver.find_element(By.XPATH, '//div[@class="postings-container"]')
        except NoSuchElementException:
            print("No se encontró el div que contiene los departamentos")
            continue
        
        # Obtener los departamentos usando un XPath relativo
        departamentos = departamentos_div.find_elements(By.XPATH, './div')
        print(f"Número de departamentos: {len(departamentos)}")
        
        for f in range(len(departamentos)):
            print(f"Departamento {f+1}")
            try:
                enlaces = departamentos[f].find_elements(By.XPATH, './/a')
                for enlace in enlaces:
                    href = enlace.get_attribute('href')
                    print(f"Href: {href}")
                    links.append(href)
            except NoSuchElementException:
                print(f"No se encontró el enlace en el departamento {f+1}")

        # Cambiar de página
        if i < numero_paginas:
            try:
                siguiente = driver.find_element(By.XPATH, '//a[@class="PageArrow-sc-n5babu-2 kTvCSV"]')
                siguiente_href = siguiente.get_attribute('href')
                driver.get(siguiente_href)
                time.sleep(3)  # Esperar un momento para que la página cargue
            except NoSuchElementException:
                print("No se encontró el botón de siguiente página")
                break
                
        wait = WebDriverWait(driver, 10)

finally:
    # Cerrar el navegador
    driver.quit()
    print("fin")
# Out:
# No se encontró el texto con la cantidad de departamentos
# fin
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 21
#      19     print("No se encontró el texto con la cantidad de departamentos")
#      20 # extraer el texto con la cantidad de departamentos dejando solo los numeros
# ---> 21 numero_despartamentos = int(''.join(filter(str.isdigit, texto_con_cantidad)))
#      23 numero_paginas = int(np.ceil(numero_despartamentos / 30))
#      25 print(f"Numero de paginas: {numero_paginas}")
#
# NameError: name 'texto_con_cantidad' is not defined

# %% [markdown]
# este lo dejo para mas adelante porque tiene un capcha

# %% [markdown]
# pasao a las siguiente inmobiliaria

# %%
#librerias 
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
import time

# %%
# Abrir el navegador Edge
driver = webdriver.Edge()

links=[]

try:
    # Página web
    url = 'http://www.estudioorcola.com/listado.php?modalidad=1&categoria=4#inicioLista'

    # Abrir la página
    driver.get(url)
        # Obtener el div que contiene los departamentos
    try:
        departamentos_div = driver.find_element(By.XPATH, '/html/body/div[5]')
    except NoSuchElementException:
        print("No se encontró el div que contiene los departamentos")
    
        
        # Obtener los departamentos usando un XPath relativo
    departamentos = departamentos_div.find_elements(By.XPATH, './a')
    print(f"Número de departamentos: {len(departamentos)}")
        
    for f in range(len(departamentos)):
        print(f"Departamento {f+1}")
        try:
            enlace = departamentos[f]
            href = enlace.get_attribute('href')
            print(f"Href: {href}")
            links.append(href)
        except NoSuchElementException:
            print(f"No se encontró el enlace en el departamento {f+1}")

            
                

finally:
    # Cerrar el navegador
    #driver.quit()
    print("fin")
# Out:
# Número de departamentos: 13
# Departamento 1
# Href: https://www.estudioorcola.com/ficha.php?codigo=19111202&modalidad=1
# Departamento 2
# Href: https://www.estudioorcola.com/ficha.php?codigo=219622&modalidad=1
# Departamento 3
# Href: https://www.estudioorcola.com/ficha.php?codigo=249450&modalidad=1
# Departamento 4
# Href: https://www.estudioorcola.com/ficha.php?codigo=2492645&modalidad=1
# Departamento 5
# Href: https://www.estudioorcola.com/ficha.php?codigo=2492603&modalidad=1
# Departamento 6
# Href: https://www.estudioorcola.com/ficha.php?codigo=2492620&modalidad=1
# Departamento 7
# Href: https://www.estudioorcola.com/ficha.php?codigo=2212327&modalidad=1
# Departamento 8
# Href: https://www.estudioorcola.com/ficha.php?codigo=1353049&modalidad=1
# Departamento 9
# Href: https://www.estudioorcola.com/ficha.php?codigo=22111936&modalidad=1
# Departamento 10
# Href: https://www.estudioorcola.com/ficha.php?codigo=249911&modalidad=1
# Departamento 11
# Href: https://www.estudioorcola.com/ficha.php?codigo=249459&modalidad=1
# Departamento 12
# Href: https://www.estudioorcola.com/ficha.php?codigo=1842446&modalidad=1
# Departamento 13
# Href: https://www.estudioorcola.com/ficha.php?codigo=242555&modalidad=1
# fin

# %%
import re

def obtener_latitud(url):
    # Expresión regular para capturar la latitud
    patron_latitud = r"!3d(-?\d+\.\d+)"
    coincidencia_latitud = re.search(patron_latitud, url)
    print(coincidencia_latitud)
    
    if coincidencia_latitud:
        latitud = float(coincidencia_latitud.group(1))
        print(latitud)
        return latitud
    else:
        return None

def obtener_longitud(url):
    # Expresión regular para capturar la longitud
    patron_longitud = r"!2d(-?\d+\.\d+)"
    coincidencia_longitud = re.search(patron_longitud, url)
    print(coincidencia_longitud)
    
    if coincidencia_longitud:
        longitud = float(coincidencia_longitud.group(1))
        print(longitud)
        return longitud
    else:
        return None

# %%
#iterar sobre los enlaces guardados en la lista links

data_orcola = []
driver = webdriver.Edge()

try:
    for enlace in links:
        bandera = True

        driver.get(enlace)
        time.sleep(3)  # Esperar un momento para que la página cargue
        
        # Obtener la información del departamento
        try:
            address = driver.find_element(By.XPATH, '//div[@class="fichaDireccion"]').text
        except NoSuchElementException:
            print("No se encontró la direccion")
            address = None
        
        try:
            price = driver.find_element(By.XPATH, '//p[@class="text-center fichaSimplificadaPrecio"]').text
        except NoSuchElementException:
            print("No se encontró el precio")
            price = None

        try:
            expensas = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[1]/div[1]/div[2]/p').text
        except NoSuchElementException:
            print("No se encontró el precio de las expensas")
            expensas = None

        try:
            descripcion = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[1]/div[1]/div[2]/div[2]/p').text
        except NoSuchElementException:
            print("No se encontró la descripción")
            descripcion = None
        
        try:
            tipo = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[1]/div[1]/div[2]/div[2]/ul/li[1]').text
        except NoSuchElementException:
            print("No se encontró el tipo")
            tipo = None

        try:
            superficie = driver.find_element(By.XPATH, '/html/body/div[4]/div[4]/div/div[3]/h1').text
        except NoSuchElementException:
            print("No se encontró la superficie")
            superficie = None
        
        try:
            cantidad_ambientes = driver.find_element(By.XPATH, '/html/body/div[4]/div[4]/div/div[1]/h1').text

        except NoSuchElementException:
            print("No se encontró la cantidad de ambientes")
            cantidad_ambientes = None

        try:
            cantidad_dormitorios = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[1]/div[1]/div[2]/div[2]/ul/li[4]').text
        except NoSuchElementException:
            print("No se encontró la cantidad de dormitorios")
            cantidad_dormitorios = None

        try:
            cantidad_banos = driver.find_element(By.XPATH, '/html/body/div[4]/div[4]/div/div[2]/h1').text
        except NoSuchElementException:
            print("No se encontró la cantidad de baños")
            cantidad_banos = None

        try:
            # obtener div de mapa de google map
            mapa = driver.find_element(By.XPATH, '//*[@id="mapas"]/div/div[1]/iframe')
        except NoSuchElementException:
            print("No se encontró el mapa")
            bandera = False


        #obtener latitud y longitud de los atributos del div

        try:
            print(mapa)
            if bandera:
                url = mapa.get_attribute('src')
                print(f"Latitud y longitud en URL: {url}")
                latitud = obtener_latitud(url)
                longitud = obtener_longitud(url)
            else:
                latitud = None
                longitud = None
        except NoSuchElementException:
            print("No se encontró la latitud y longitud")

            
        departamento_info = {
            "enlace": enlace,
            "address": address,
            "price": price,
            "expensas": expensas,
            "tipo": tipo,
            "superficie": superficie,
            "cantidad_ambientes": cantidad_ambientes,
            "cantidad_dormitorios": cantidad_dormitorios,
            "cantidad_banos": cantidad_banos,
            "latitud": latitud,
            "longitud": longitud
        }

        data_orcola.append(departamento_info)

        print(departamento_info)


finally:
    driver.quit()
    print("fin")
# Out:
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.C10547E75E0878065CF0567C22DCA435.e.35")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3540.920301697664!2d-58.99141838433268!3d-27.440594422036764!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450c676338b801%3A0x292c13e101fd9648!2sAv.%20Rivadavia%20810%2C%20H3502ALS%20Resistencia%2C%20Chaco!5e0!3m2!1ses!2sar!4v1573559973245!5m2!1ses!2sar
# <re.Match object; span=(92, 114), match='!3d-27.440594422036764'>
# -27.440594422036764
# <re.Match object; span=(71, 92), match='!2d-58.99141838433268'>
# -58.99141838433268
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=19111202&modalidad=1', 'address': 'Avenida Rivadavia 810 - Macrocentro', 'price': '$ 430.000', 'expensas': None, 'tipo': None, 'superficie': '50', 'cantidad_ambientes': '2', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': -27.440594422036764, 'longitud': -58.99141838433268}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.B02895D774DD2D230E8A0E0B91C83384.e.70")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d1488.4619050747976!2d-58.986304669899994!3d-27.463686905372807!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450ceb857a7ecd%3A0xd071f65846e2e745!2sLas%20Heras%20766%2C%20H3500COI%20Resistencia%2C%20Chaco!5e0!3m2!1ses!2sar!4v1630934502387!5m2!1ses!2sar
# <re.Match object; span=(94, 116), match='!3d-27.463686905372807'>
# -27.463686905372807
# <re.Match object; span=(72, 94), match='!2d-58.986304669899994'>
# -58.986304669899994
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=219622&modalidad=1', 'address': 'Las Heras 766 - U.N.N.E.', 'price': '$ 290.000', 'expensas': None, 'tipo': None, 'superficie': '36', 'cantidad_ambientes': 'Mono', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': -27.463686905372807, 'longitud': -58.986304669899994}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.A8E2EBC4F62D211D61E966D9B99E5C09.e.104")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d14162.165298581895!2d-58.99553691597487!3d-27.452401889157738!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450cec0d347e81%3A0x294949388fe5f790!2sFausto%20I!5e0!3m2!1sen!2sar!4v1725454156916!5m2!1sen!2sar
# <re.Match object; span=(93, 115), match='!3d-27.452401889157738'>
# -27.452401889157738
# <re.Match object; span=(72, 93), match='!2d-58.99553691597487'>
# -58.99553691597487
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=249450&modalidad=1', 'address': 'Franklin 756 - Zona Unne', 'price': '230.000', 'expensas': None, 'tipo': None, 'superficie': '35', 'cantidad_ambientes': 'MONO', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': -27.452401889157738, 'longitud': -58.99553691597487}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.52289735F013CDD076C390A4F99E1ED9.e.138")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d7081.413451701266!2d-58.99958712228998!3d-27.44724919999998!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450c601a9dba73%3A0x4bcdf08ceca0d87!2sEdificio%20Centenario!5e0!3m2!1sen!2sar!4v1727361782140!5m2!1sen!2sar
# <re.Match object; span=(92, 113), match='!3d-27.44724919999998'>
# -27.44724919999998
# <re.Match object; span=(71, 92), match='!2d-58.99958712228998'>
# -58.99958712228998
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=2492645&modalidad=1', 'address': 'Avenida Wilde 12 - Micro Centro', 'price': '$ 400.000', 'expensas': None, 'tipo': None, 'superficie': '-', 'cantidad_ambientes': '2', 'cantidad_dormitorios': None, 'cantidad_banos': '2', 'latitud': -27.44724919999998, 'longitud': -58.99958712228998}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.1ED64CCA9C0A47017D3F1B743B66F29D.e.173")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3540.1089238495006!2d-58.993592225533575!3d-27.46586811654118!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450c94e7d14297%3A0xc7220c6c66cd8e5d!2sSan%20Lorenzo%201180%2C%20H3506%20Resistencia%2C%20Chaco!5e0!3m2!1sen!2sar!4v1727362771247!5m2!1sen!2sar
# <re.Match object; span=(94, 115), match='!3d-27.46586811654118'>
# -27.46586811654118
# <re.Match object; span=(72, 94), match='!2d-58.993592225533575'>
# -58.993592225533575
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=2492603&modalidad=1', 'address': 'San Lorenzo 1180 - Zona Unne', 'price': '$ 200.000', 'expensas': None, 'tipo': None, 'superficie': '-', 'cantidad_ambientes': '1', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': -27.46586811654118, 'longitud': -58.993592225533575}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.6977641A301A78B5F95BD42786A0AAEB.e.207")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3540.746891440481!2d-58.984368999999994!3d-27.445997799999994!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450c5f50f9fde7%3A0xec5729c899fa8a38!2sPueyrred%C3%B3n%20455%2C%20H3500BNI%20Resistencia%2C%20Chaco!5e0!3m2!1sen!2sar!4v1727360021085!5m2!1sen!2sar
# <re.Match object; span=(93, 115), match='!3d-27.445997799999994'>
# -27.445997799999994
# <re.Match object; span=(71, 93), match='!2d-58.984368999999994'>
# -58.984368999999994
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=2492620&modalidad=1', 'address': 'Pueyrredon 455 - Micro Centro', 'price': '$ 380.000', 'expensas': None, 'tipo': None, 'superficie': '-', 'cantidad_ambientes': '2', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': -27.445997799999994, 'longitud': -58.984368999999994}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.CF4959AFF736F24C8CE56BAB1E462761.e.241")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d2105.355106969549!2d-58.97993709895659!3d-27.445242766518273!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450c5877e6ea99%3A0x4c5b7ce6574b637d!2sAv.%20Sarmiento%20764%2C%20H3502FJE%20Resistencia%2C%20Chaco!5e0!3m2!1ses!2sar!4v1670876933230!5m2!1ses!2sar
# <re.Match object; span=(92, 114), match='!3d-27.445242766518273'>
# -27.445242766518273
# <re.Match object; span=(71, 92), match='!2d-58.97993709895659'>
# -58.97993709895659
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=2212327&modalidad=1', 'address': 'Avenida Sarmiento 764 - Macrocentro', 'price': '$ 280.000', 'expensas': None, 'tipo': None, 'superficie': '40', 'cantidad_ambientes': 'Mono', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': -27.445242766518273, 'longitud': -58.97993709895659}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.A29982B6AD6DDF7E6A6D538CB575DB70.e.275")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3540.3453613058123!2d-58.99587712553389!3d-27.458505516227586!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450c8d8e193389%3A0x1f1f58f491cc9a09!2sFrondizi%20850%2C%20H3506%20Resistencia%2C%20Chaco!5e0!3m2!1sen!2sar!4v1727211597247!5m2!1sen!2sar
# <re.Match object; span=(93, 115), match='!3d-27.458505516227586'>
# -27.458505516227586
# <re.Match object; span=(72, 93), match='!2d-58.99587712553389'>
# -58.99587712553389
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=1353049&modalidad=1', 'address': 'Frondizi 850 - Macrocentro', 'price': '$ 270.000', 'expensas': None, 'tipo': None, 'superficie': '65', 'cantidad_ambientes': '2', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': -27.458505516227586, 'longitud': -58.99587712553389}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# No se encontró el mapa
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.A29982B6AD6DDF7E6A6D538CB575DB70.e.275")>
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=22111936&modalidad=1', 'address': 'Av. Sarmiento 440 - Macrocentro', 'price': '$ 400.000', 'expensas': None, 'tipo': None, 'superficie': '86', 'cantidad_ambientes': '2', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.368373059A93BF1A4610F50F0328389B.e.340")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3540.2288784297025!2d-58.991469698149885!3d-27.462132989906937!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450c933cb452e9%3A0x71c77ed58a3070e6!2sLeandro%20N.%20Alem%20495%2C%20H3508BNT%20Resistencia%2C%20Chaco!5e0!3m2!1sen!2sar!4v1725919543070!5m2!1sen!2sar
# <re.Match object; span=(94, 116), match='!3d-27.462132989906937'>
# -27.462132989906937
# <re.Match object; span=(72, 94), match='!2d-58.991469698149885'>
# -58.991469698149885
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=249911&modalidad=1', 'address': 'Alem 495 - -', 'price': '$ 200.000', 'expensas': None, 'tipo': None, 'superficie': '35', 'cantidad_ambientes': '1', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': -27.462132989906937, 'longitud': -58.991469698149885}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.99434D45A8E237FD92847CEE228673B7.e.374")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3540.9254367943468!2d-58.9975094!3d-27.440434399999997!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450c65a26159d3%3A0x8cd3033c4d621b5!2sRoberto%20Mora%2060%2C%20H3502%20Resistencia%2C%20Chaco!5e0!3m2!1sen!2sar!4v1725454731015!5m2!1sen!2sar
# <re.Match object; span=(86, 108), match='!3d-27.440434399999997'>
# -27.440434399999997
# <re.Match object; span=(72, 86), match='!2d-58.9975094'>
# -58.9975094
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=249459&modalidad=1', 'address': 'Roberto Mora 60 - Macro Centro', 'price': '$ 230.000', 'expensas': None, 'tipo': None, 'superficie': '38', 'cantidad_ambientes': '1', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': -27.440434399999997, 'longitud': -58.9975094}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.3EB83480D8149A41B9786D0FEB7D971B.e.408")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3540.2436217346085!2d-58.98364868535006!3d-27.461673882894253!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x94450ce9327c7957%3A0x358319483d49d21d!2sAmeghino+935%2C+H3500AEP+Resistencia%2C+Chaco!5e0!3m2!1ses!2sar!4v1524573915689
# <re.Match object; span=(93, 115), match='!3d-27.461673882894253'>
# -27.461673882894253
# <re.Match object; span=(72, 93), match='!2d-58.98364868535006'>
# -58.98364868535006
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=1842446&modalidad=1', 'address': 'Ameghino 935 - UNNE', 'price': '$ 35.000', 'expensas': None, 'tipo': None, 'superficie': '98', 'cantidad_ambientes': '3', 'cantidad_dormitorios': None, 'cantidad_banos': '2', 'latitud': -27.461673882894253, 'longitud': -58.98364868535006}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# <selenium.webdriver.remote.webelement.WebElement (session="d47f2ab83b39fad8806d1ae357321901", element="f.9BC9647DAC5F0965177034788A901E24.d.4C98691F3C821922DB2F2D36D4584776.e.443")>
# Latitud y longitud en URL: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3284.197625158787!2d-58.379262826539666!3d-34.59916387295591!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x95bccacbc0eafe09%3A0x297e00f03a983ffc!2sMaip%C3%BA%20763%2C%20C1006%20San%20Nicolas%2C%20Buenos%20Aires!5e0!3m2!1ses-419!2sar!4v1707166265073!5m2!1ses-419!2sar
# <re.Match object; span=(93, 114), match='!3d-34.59916387295591'>
# -34.59916387295591
# <re.Match object; span=(71, 93), match='!2d-58.379262826539666'>
# -58.379262826539666
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=242555&modalidad=1', 'address': 'Maipu 763 (CABA) - Galerias Pacifico (ALQUILER TEMPORARIO)', 'price': 'Consultar Precio', 'expensas': None, 'tipo': None, 'superficie': '38', 'cantidad_ambientes': 'Mono', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': -34.59916387295591, 'longitud': -58.379262826539666}
# fin

# %%
#lista a data frame
df_orcola = pd.DataFrame(data_orcola)
df_orcola.to_csv('departamentos_orcola.csv', index=False)

# %% [markdown]
# siguiente paguina

# %%
# Abrir el navegador Edge
driver = webdriver.Edge()

links=[]

try:
    # Página web
    url = 'https://www.amudpropiedades.com/propiedades.aspx?d=1&operacion=Alquiler&producto=Departamentos&pais=Argentina&provincia=CHACO'

    # Abrir la página
    driver.get(url)
    '''
    # Obtener el elemento entre pagination__separator y pagination__page-next
    try:
        texto_con_cantidad = driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/div/div/div[2]/div[2]/div[1]/div/div[1]/h1').text
    except NoSuchElementException:
        print("No se encontró el texto con la cantidad de departamentos")
    # extraer el texto con la cantidad de departamentos dejando solo los numeros
    numero_despartamentos = int(''.join(filter(str.isdigit, texto_con_cantidad)))

    numero_paginas = int(np.ceil(numero_despartamentos / 30))

    print(f"Numero de paginas: {numero_paginas}")



    for i in range(1, numero_paginas + 1):
        print(f"Página {i}")
        
        # Obtener el div que contiene los departamentos
        try:
            departamentos_div = driver.find_element(By.XPATH, '//div[@class="postings-container"]')
        except NoSuchElementException:
            print("No se encontró el div que contiene los departamentos")
            continue
        
        # Obtener los departamentos usando un XPath relativo
        departamentos = departamentos_div.find_elements(By.XPATH, './div')
        print(f"Número de departamentos: {len(departamentos)}")
        
        for f in range(len(departamentos)):
            print(f"Departamento {f+1}")
            try:
                enlaces = departamentos[f].find_elements(By.XPATH, './/a')
                for enlace in enlaces:
                    href = enlace.get_attribute('href')
                    print(f"Href: {href}")
                    links.append(href)
            except NoSuchElementException:
                print(f"No se encontró el enlace en el departamento {f+1}")

        # Cambiar de página
        if i < numero_paginas:
            try:
                siguiente = driver.find_element(By.XPATH, '//a[@class="PageArrow-sc-n5babu-2 kTvCSV"]')
                siguiente_href = siguiente.get_attribute('href')
                driver.get(siguiente_href)
                time.sleep(3)  # Esperar un momento para que la página cargue
            except NoSuchElementException:
                print("No se encontró el botón de siguiente página")
                break
                
        '''

finally:
    # Cerrar el navegador
    driver.quit()
    print("fin")
