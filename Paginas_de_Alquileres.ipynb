# %% [markdown]
# paguinas de alquileres

# %% [markdown]
#     https://www.argenprop.com/departamentos/alquiler/resistencia
#
#    https://urbanoinmobiliaria.com.ar/s/alquileres
#
#     https://www.zonaprop.com.ar/departamentos-alquiler-resistencia.html
#
#     http://www.estudioorcola.com/listado.php?modalidad=1&categoria=4#inicioLista
#
#     https://marcelorodriguezinmobiliaria.com.ar/listing?user_id=773&purpose=rent&page=2
#
#     https://danilomarcon.com/category/alquiler/
#
#     https://www.amudpropiedades.com/propiedades.aspx?d=1&operacion=Alquiler
#
#     https://urbanoinmobiliaria.com.ar/
#
#     https://www.gagoprop.com/
#
#     https://www.zonaprop.com.ar/inmuebles-venta-resistencia.html
#
#     https://www.sion-inmobiliaria.com.ar/
#
#     https://www.caravacapazos.com/propiedades.php?codop=2
#
#
#     https://www.facebook.com/groups/1569536426610628/?locale=es_LA
#
#
#     https://inmuebles.adinco.net/departamentos/alquiler/resistencia
#
#     https://www.inmobiliarialyder.com.ar/estado/en-alquiler/

# %%
#librerias 
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
import time

# %% [markdown]
# 1

# %% [markdown]
# argenprop alquileres

# %%
# Abrir el navegador Edge
driver = webdriver.Edge()

links=[]

try:
    # Página web
    url = 'https://www.argenprop.com/departamentos/alquiler/resistencia'

    # Abrir la página
    driver.get(url)

    # Obtener el elemento entre pagination__separator y pagination__page-next
    elemento = driver.find_element(By.XPATH, '//li[@class="pagination__separator"]/following-sibling::li[1][not(contains(@class, "pagination__page-next"))]')

    # Convertir el texto del elemento a un número entero
    numero_paginas = int(elemento.text)

    for i in range(1, numero_paginas + 1):
        print(f"Página {i}")
        
        # Obtener el div que contiene los departamentos
        try:
            departamentos_div = driver.find_element(By.XPATH, '//div[@class="listing__items"]')
        except NoSuchElementException:
            print("No se encontró el div que contiene los departamentos")
            continue
        
        # Obtener los departamentos usando un XPath relativo
        departamentos = departamentos_div.find_elements(By.XPATH, './div')
        print(f"Número de departamentos: {len(departamentos)}")
        
        for f in range(len(departamentos)):
            print(f"Departamento {f+1}")
            try:
                enlaces = departamentos[f].find_elements(By.XPATH, './/a')
                for enlace in enlaces:
                    href = enlace.get_attribute('href')
                    print(f"Href: {href}")
                    links.append(href)
            except NoSuchElementException:
                print(f"No se encontró el enlace en el departamento {f+1}")
        
        # Cambiar de página
        if i < numero_paginas:
            try:
                siguiente = driver.find_element(By.XPATH, '//li[@class="pagination__page-next pagination__page"]/a')
                siguiente_href = siguiente.get_attribute('href')
                driver.get(siguiente_href)
                time.sleep(3)  # Esperar un momento para que la página cargue
            except NoSuchElementException:
                print("No se encontró el botón de siguiente página")
                break
finally:
    # Cerrar el navegador
    driver.quit()
# Out:
# Página 1
# Número de departamentos: 22
# Departamento 1
# Href: https://www.argenprop.com/departamento-en-alquiler-en-resistencia-2-ambientes--16364770
# Departamento 2
# Href: https://www.argenprop.com/departamento-en-alquiler-en-resistencia-3-ambientes--6559009
# Departamento 3
# Departamento 4
# Href: https://www.argenprop.com/departamento-en-alquiler-en-resistencia-5-ambientes--9046760
# Departamento 5
# Href: https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-2-ambientes--16300625
# Departamento 6
# Href: https://www.argenprop.com/departamento-en-alquiler-en-zona-unne-1-ambiente--16361737
# Departamento 7
# Href: https://www.argenprop.com/departamento-en-alquiler-en-zona-residencial-2-ambientes--8106500
# Departamento 8
# Departamento 9
# Href: https://www.argenprop.com/departamento-en-alquiler-en-resistencia-1-ambiente--9688176
# Departamento 10
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-4-ambientes--15195540
# Departamento 11
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-1-ambiente--8244066
# Departamento 12
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-san-juan-1-ambiente--12993799
# Departamento 13
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-asuncion-1-ambiente--15901269
# Departamento 14
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-maria-4-ambientes--8445979
# Departamento 15
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16094517
# Departamento 16
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-asuncion-2-ambientes--8302316
# Departamento 17
# Href: https://www.argenprop.com/departamento-en-alquiler-en-microcentro-3-ambientes--16101071
# Departamento 18
# Href: https://www.argenprop.com/departamento-en-alquiler-en-microcentro-4-ambientes--16193250
# Departamento 19
# Href: https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-4-ambientes--16193274
# Departamento 20
# Href: https://www.argenprop.com/departamento-en-alquiler-en-zona-unne-4-ambientes--16215932
# Departamento 21
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-4-ambientes--16255465
# Departamento 22
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--8946686
# Página 2
# Número de departamentos: 22
# Departamento 1
# Href: https://www.argenprop.com/departamento-en-alquiler-en-resistencia--16296093
# Departamento 2
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-centenario-2-ambientes--16296262
# Departamento 3
# Departamento 4
# Href: https://www.argenprop.com/departamento-en-alquiler-en-los-troncos-2-ambientes--16296352
# Departamento 5
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16300989
# Departamento 6
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-del-oeste-3-ambientes--8478963
# Departamento 7
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-alta-1-ambiente--9047880
# Departamento 8
# Departamento 9
# Href: https://www.argenprop.com/departamento-en-alquiler-en-nueva-resistencia-3-ambientes--16349490
# Departamento 10
# Href: https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-2-ambientes--16349527
# Departamento 11
# Href: https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-1-ambiente--10207131
# Departamento 12
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-centenario-2-ambientes--15481686
# Departamento 13
# Href: https://www.argenprop.com/departamento-en-alquiler-en-resistencia-1-ambiente--15771825
# Departamento 14
# Href: https://www.argenprop.com/departamento-en-alquiler-en-resistencia-4-ambientes--16376382
# Departamento 15
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-4-ambientes--13008260
# Departamento 16
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--13058843
# Departamento 17
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--14425576
# Departamento 18
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--6581493
# Departamento 19
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--14572138
# Departamento 20
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--14906492
# Departamento 21
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--11616830
# Departamento 22
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-5-ambientes--15283675
# Página 3
# Número de departamentos: 22
# Departamento 1
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--15288168
# Departamento 2
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--15330808
# Departamento 3
# Departamento 4
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--15403803
# Departamento 5
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-1-ambiente--15529006
# Departamento 6
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-1-ambiente--15536757
# Departamento 7
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--15853411
# Departamento 8
# Departamento 9
# Href: https://www.argenprop.com/departamento-en-alquiler-en-espana-2-ambientes--6581505
# Departamento 10
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--15897072
# Departamento 11
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--6581402
# Departamento 12
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-del-parque-1-ambiente--16010187
# Departamento 13
# Href: https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-2-ambientes--16042085
# Departamento 14
# Href: https://www.argenprop.com/departamento-en-alquiler-en-espana-3-ambientes--16071370
# Departamento 15
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-centenario-3-ambientes--16098191
# Departamento 16
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16098223
# Departamento 17
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--16140470
# Departamento 18
# Href: https://www.argenprop.com/departamento-en-alquiler-en-santa-rita-3-ambientes--16143834
# Departamento 19
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-alta-2-ambientes--16143898
# Departamento 20
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--16204446
# Departamento 21
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16204447
# Departamento 22
# Href: https://www.argenprop.com/departamento-en-alquiler-en-llaponagat-4-ambientes--16218604
# Página 4
# Número de departamentos: 22
# Departamento 1
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-central-norte-1-ambiente--16220727
# Departamento 2
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-del-parque-2-ambientes--16139434
# Departamento 3
# Departamento 4
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16244431
# Departamento 5
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--9387008
# Departamento 6
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-central-norte-1-ambiente--16272553
# Departamento 7
# Href: https://www.argenprop.com/departamento-en-alquiler-en-resistencia-4-ambientes--16276040
# Departamento 8
# Departamento 9
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-alta-1-ambiente--16292884
# Departamento 10
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16298133
# Departamento 11
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--16300177
# Departamento 12
# Href: https://www.argenprop.com/departamento-en-alquiler-en-resistencia-2-ambientes--16306793
# Departamento 13
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-del-carmen-2-ambientes--16312456
# Departamento 14
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16319376
# Departamento 15
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--15313516
# Departamento 16
# Href: https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-1-ambiente--6581256
# Departamento 17
# Href: https://www.argenprop.com/departamento-en-alquiler-en-resistencia-3-ambientes--16334061
# Departamento 18
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-4-ambientes--16347647
# Departamento 19
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--16347658
# Departamento 20
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-5-ambientes--15814437
# Departamento 21
# Href: https://www.argenprop.com/departamento-en-alquiler-en-llaponagat-3-ambientes--16361963
# Departamento 22
# Href: https://www.argenprop.com/departamento-en-alquiler-en-villa-centenario-2-ambientes--6582167
# Página 5
# Número de departamentos: 1
# Departamento 1
# Href: https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--16373452

# %%
# iterar sobre los enlaces guardados en la lista links
data_argenprop = []


driver = webdriver.Edge()
try:
    for enlace in links:

        driver.get(enlace)
        time.sleep(3)  # Esperar un momento para que la página cargue
        
        # Obtener la información del departamento
        try:
            address = driver.find_element(By.XPATH, '//h2[@class="titlebar__address"]').text
        except NoSuchElementException:
            print("No se encontró la direccion")
            address = None
        
        try:
            price = driver.find_element(By.XPATH, '//p[@class="titlebar__price"]').text
        except NoSuchElementException:
            print("No se encontró el precio")
            price = None
        
        
        #div de descripcion
        try:
            expensas = driver.find_element(By.XPATH, '//p[@class="titlebar__expenses hide-in-mobile"]').text
        except NoSuchElementException:
            print("No se encontró el precio de las expensas")
            expensas = None
        
        try:
            descripcion = driver.find_element(By.XPATH, '//div[@class="property-description"]/ul[@class="property-main-features"]')
        except NoSuchElementException:
            print("No se encontró la descripción")
            descripcion = None
            
            
        try:
            tipo = descripcion.find_element(By.XPATH, './li[1]').text
        except NoSuchElementException:
            print("No se encontró el tipo")
            tipo = None
            
        try:
            superficie = descripcion.find_element(By.XPATH, './li[@title="Sup. cubierta"]').text
        except NoSuchElementException:
            print("No se encontró la superficie")
            superficie = None
            
        try:
            cantidad_ambientes = descripcion.find_element(By.XPATH, './li[@title="Ambientes"]').text
        except NoSuchElementException:
            print("No se encontró la cantidad de ambientes")
            cantidad_ambientes = None
            
        try:
            cantidad_dormitorios = descripcion.find_element(By.XPATH, './li[@title="Dormitorios"]').text
        except NoSuchElementException:
            print("No se encontró la cantidad de dormitorios")
            cantidad_dormitorios = None
            
        try:
            cantidad_banos = descripcion.find_element(By.XPATH, './li[@title="Baños"]').text
        except NoSuchElementException:
            print("No se encontró la cantidad de baños")
            cantidad_banos = None
            
        try:
            # obtener div de mapa de google map
            mapa = driver.find_element(By.XPATH, '//div[@class="leaflet-container leaflet-fade-anim leaflet-grab leaflet-touch-drag"]')
        except NoSuchElementException:
            print("No se encontró el mapa")
            
        
        #obtener latitud y longitud de los atributos del div
        try:
            latitud = mapa.get_attribute('data-latitude')
        except NoSuchElementException:
            print("No se encontró la latitud")
            latitud = None
            
        try:
            longitud = mapa.get_attribute('data-longitude')
        except NoSuchElementException:
            print("No se encontró la longitud")
            longitud = None
            
        departamento_info = {
            "enlace": enlace,
            "address": address,
            "price": price,
            "expensas": expensas,
            "tipo": tipo,
            "superficie": superficie,
            "cantidad_ambientes": cantidad_ambientes,
            "cantidad_dormitorios": cantidad_dormitorios,
            "cantidad_banos": cantidad_banos,
            "latitud": latitud,
            "longitud": longitud
        }
        
        print(departamento_info)     
        
        data_argenprop.append(departamento_info)   



finally:
    driver.quit()
# Out:
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-resistencia-2-ambientes--16364770', 'address': 'Arbo Y Blanco 800, Piso 1', 'price': '$ 320.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '45 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,46236', 'longitud': '-58,98879'}
# No se encontró la superficie
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-resistencia-3-ambientes--6559009', 'address': 'Arbo Y Blanco 800, Piso 2°', 'price': '$ 350.000', 'expensas': '+ $15.000 expensas', 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,46245', 'longitud': '-58,98872'}
# No se encontró la superficie
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-resistencia-5-ambientes--9046760', 'address': 'Av. Alberdi 200, Piso 6', 'price': '$ 550.000', 'expensas': '+ $130.000 expensas', 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': '5 ambientes', 'cantidad_dormitorios': '4 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,4529', 'longitud': '-58,98876'}
# No se encontró la superficie
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-2-ambientes--16300625', 'address': 'Catamarca 1300, Piso 3', 'price': '$ 200.000', 'expensas': '+ $30.000 expensas', 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-28,46958', 'longitud': '-65,77954'}
# No se encontró el precio de las expensas
# No se encontró la superficie
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-zona-unne-1-ambiente--16361737', 'address': 'Arbo Y Blanco 1300', 'price': '$ 200.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,46728', 'longitud': '-58,99368'}
# No se encontró el precio de las expensas
# No se encontró la superficie
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-zona-residencial-2-ambientes--8106500', 'address': 'Fray Capelli 100', 'price': '$ 320.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,44072', 'longitud': '-59,00003'}
# No se encontró la superficie
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-resistencia-1-ambiente--9688176', 'address': 'Las Heras 700, Piso 3', 'price': '$ 240.000', 'expensas': '+ $51.300 expensas', 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,46324', 'longitud': '-58,98612'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-4-ambientes--15195540', 'address': 'JUSTO JUAN B. 100', 'price': '$ 400.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '90 m² cubie.', 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '3 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,452848', 'longitud': '-58,986137'}
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-1-ambiente--8244066', 'address': 'PERON JUAN DOMINGO 700', 'price': '$ 150.000', 'expensas': '+ $15.000 expensas', 'tipo': 'Departamento', 'superficie': '23 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,446608', 'longitud': '-58,994915'}
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-san-juan-1-ambiente--12993799', 'address': 'PARODI 200', 'price': '$ 95.000', 'expensas': '+ $20.000 expensas', 'tipo': 'Departamento', 'superficie': '20 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,46824', 'longitud': '-58,971584'}
# No se encontró el precio de las expensas
# No se encontró la superficie
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-asuncion-1-ambiente--15901269', 'address': 'Zorrilla 600', 'price': '$ 100.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-26,58577', 'longitud': '-60,95401'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-maria-4-ambientes--8445979', 'address': 'JULIO A. ROCA 1000', 'price': '$ 370.000', 'expensas': '+ $30.000 expensas', 'tipo': 'Departamento', 'superficie': '75 m² cubie.', 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '3 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,443851', 'longitud': '-58,996346'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16094517', 'address': 'NECOCHEA 200', 'price': '$ 260.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '45 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,45056', 'longitud': '-58,991222'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-asuncion-2-ambientes--8302316', 'address': 'HERNANDEZ 1000', 'price': '$ 160.000', 'expensas': '+ $2.500 expensas', 'tipo': 'Departamento', 'superficie': '40 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,448154', 'longitud': '-58,97071'}
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-microcentro-3-ambientes--16101071', 'address': 'PJE DEL TEATRO 100', 'price': '$ 320.000', 'expensas': '+ $10.000 expensas', 'tipo': 'Departamento', 'superficie': '60 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': None, 'latitud': '-27,456676', 'longitud': '-58,99014'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-microcentro-4-ambientes--16193250', 'address': 'LOPEZ Y PLANES 600', 'price': '$ 390.000', 'expensas': '+ $170.000 expensas', 'tipo': 'Departamento', 'superficie': '95 m² cubie.', 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '3 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,448084', 'longitud': '-58,97801'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-4-ambientes--16193274', 'address': 'PUEYRREDON 400', 'price': '$ 450.000', 'expensas': '+ $20.000 expensas', 'tipo': 'Departamento', 'superficie': '70 m² cubie.', 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '3 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,447077', 'longitud': '-58,985634'}
# No se encontró el precio de las expensas
# No se encontró la superficie
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-zona-unne-4-ambientes--16215932', 'address': 'Av Chaco 1300', 'price': '$ 350.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '3 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,47415', 'longitud': '-58,98439'}
# No se encontró el precio de las expensas
# No se encontró la superficie
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-4-ambientes--16255465', 'address': 'Arbo Y Blanco 200, Piso 1', 'price': '$ 300.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '3 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,45746', 'longitud': '-58,98326'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--8946686', 'address': 'NECOCHEA 100', 'price': '$ 210.000', 'expensas': '+ $15.000 expensas', 'tipo': 'Departamento', 'superficie': '30 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,449608', 'longitud': '-58,99009'}
# No se encontró la superficie
# No se encontró la cantidad de ambientes
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-resistencia--16296093', 'address': 'Alte G Brown 100, Piso 14', 'price': '$ 450.000', 'expensas': '+ $100.000 expensas', 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': None, 'cantidad_dormitorios': '3 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,450562', 'longitud': '-58,98345'}
# No se encontró el precio de las expensas
# No se encontró la superficie
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-centenario-2-ambientes--16296262', 'address': 'Jose M Paz 900', 'price': '$ 160.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-34,73257', 'longitud': '-58,4285'}
# No se encontró la superficie
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-los-troncos-2-ambientes--16296352', 'address': 'Av. Rissione 600, Piso 2', 'price': '$ 350.000', 'expensas': '+ $18.000 expensas', 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,44341', 'longitud': '-58,96642'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16300989', 'address': 'Av. Chaco 1500', 'price': '$ 250.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '33 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,4761', 'longitud': '-58,98611'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-del-oeste-3-ambientes--8478963', 'address': '1º DE MAYO 1100', 'price': '$ 150.000', 'expensas': '+ $15.000 expensas', 'tipo': 'Departamento', 'superficie': '60 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,456268', 'longitud': '-59,00619'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de dormitorios
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-alta-1-ambiente--9047880', 'address': 'SICAS 100', 'price': '$ 95.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '24 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': None, 'latitud': '-27,436663', 'longitud': '-59,002605'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-resistencia-3-ambientes--16349490', 'address': 'Mz. 69 - Uf. 16 - Barrio Nueva Resistencia 100', 'price': '$ 220.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '55 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,441229', 'longitud': '-59,020306'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-2-ambientes--16349527', 'address': 'ALEM LEANDRO N. 400', 'price': '$ 250.000', 'expensas': '+ $15.000 expensas', 'tipo': 'Departamento', 'superficie': '40 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,461796', 'longitud': '-58,990616'}
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-1-ambiente--10207131', 'address': 'CORRIENTES 700', 'price': '$ 270.000', 'expensas': '+ $40.000 expensas', 'tipo': 'Departamento', 'superficie': '38 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,44282', 'longitud': '-58,990257'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-centenario-2-ambientes--15481686', 'address': 'SAN MARTIN 1000', 'price': 'Consultar precio', 'expensas': '+ $15.000 expensas', 'tipo': 'Departamento', 'superficie': '40 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,4636', 'longitud': '-58,991474'}
# No se encontró la superficie
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-resistencia-1-ambiente--15771825', 'address': 'Pasaje Wilde 1100', 'price': '$ 100.000', 'expensas': '+ $7.000 expensas', 'tipo': 'Departamento', 'superficie': None, 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,43835', 'longitud': '-58,98016'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-resistencia-4-ambientes--16376382', 'address': 'av piacentini 1300, Piso 1', 'price': '$ 400.000', 'expensas': '+ $115.000 expensas', 'tipo': 'Departamento', 'superficie': '76 m² cubie.', 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,47154', 'longitud': '-58,986313'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-4-ambientes--13008260', 'address': 'AV PARAGUAY 100', 'price': '$ 220.000', 'expensas': '+ $48.000 expensas', 'tipo': 'Departamento', 'superficie': '140 m² cubie.', 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '3 dorm.', 'cantidad_banos': '4 baños', 'latitud': '-27,44806', 'longitud': '-58,981457'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--13058843', 'address': 'AV.9 DE JULIO 700', 'price': '$ 200.000', 'expensas': '+ $15.000 expensas', 'tipo': 'Departamento', 'superficie': '45 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-26,585766', 'longitud': '-60,954006'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--14425576', 'address': 'IRIGOYEN 400', 'price': '$ 80.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '70 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': None, 'latitud': '-27,453304', 'longitud': '-58,982132'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--6581493', 'address': 'AV LAS HERAS 700, Piso 2', 'price': '$ 120.000', 'expensas': '+ $50.000 expensas', 'tipo': 'Departamento', 'superficie': '55 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,462883', 'longitud': '-58,985634'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--14572138', 'address': 'JUAN D.PERON 600', 'price': '$ 100.000', 'expensas': '+ $35.000 expensas', 'tipo': 'Departamento', 'superficie': '55 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,44803', 'longitud': '-58,99352'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--14906492', 'address': 'GARCIA MEROU 200', 'price': '$ 160.000', 'expensas': '+ $40.000 expensas', 'tipo': 'Departamento', 'superficie': '55 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,45666', 'longitud': '-58,996166'}
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--11616830', 'address': 'AV.BELGRANO 100', 'price': '$ 150.000', 'expensas': '+ $50.000 expensas', 'tipo': 'Departamento', 'superficie': '45 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': None, 'latitud': '-27,448004', 'longitud': '-58,991825'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-5-ambientes--15283675', 'address': 'AV.CASTELLI 400', 'price': '$ 250.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '200 m² cubie.', 'cantidad_ambientes': '5 ambientes', 'cantidad_dormitorios': '4 dorm.', 'cantidad_banos': None, 'latitud': '-27,460798', 'longitud': '-58,990322'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--15288168', 'address': 'JUAN B.JUSTO 100', 'price': '$ 230.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '70 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,452702', 'longitud': '-58,98649'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--15330808', 'address': 'AV.9 DE JULIO 300', 'price': '$ 200.000', 'expensas': '+ $40.000 expensas', 'tipo': 'Departamento', 'superficie': '75 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-26,585766', 'longitud': '-60,954006'}
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--15403803', 'address': 'JUAN B.JUSTO 100', 'price': '$ 200.000', 'expensas': '+ $50.000 expensas', 'tipo': 'Departamento', 'superficie': '65 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': None, 'latitud': '-27,452702', 'longitud': '-58,98649'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de dormitorios
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-1-ambiente--15529006', 'address': 'ARBO Y BLANCO 800', 'price': '$ 100.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '35 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': None, 'latitud': '-27,462057', 'longitud': '-58,98817'}
# No se encontró la cantidad de dormitorios
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-1-ambiente--15536757', 'address': 'AV.LAS HERAS 700', 'price': '$ 150.000', 'expensas': '+ $50.000 expensas', 'tipo': 'Departamento', 'superficie': '35 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': None, 'latitud': '-27,462831', 'longitud': '-58,985558'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--15853411', 'address': 'FORMOSA 400', 'price': '$ 650.000', 'expensas': '+ $120.000 expensas', 'tipo': 'Departamento', 'superficie': '65 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,442028', 'longitud': '-58,988285'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de baños
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-espana-2-ambientes--6581505', 'address': 'HNOS.PINZON 1500, Piso P.B.', 'price': '$ 150.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '45 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': None, 'latitud': '-27,445766', 'longitud': '-59,018402'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--15897072', 'address': 'Av.Avalos 500', 'price': '$ 280.000', 'expensas': '+ $50.000 expensas', 'tipo': 'Departamento', 'superficie': '75 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,440973', 'longitud': '-58,98908'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--6581402', 'address': 'CONCEP. DEL BERMEJO 200, Piso 3', 'price': '$ 320.000', 'expensas': '+ $30.000 expensas', 'tipo': 'Departamento', 'superficie': '54 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,441618', 'longitud': '-58,993656'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-del-parque-1-ambiente--16010187', 'address': 'AV MARCONI 100', 'price': '$ 140.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '32 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,462788', 'longitud': '-59,00172'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-2-ambientes--16042085', 'address': 'RODRIGUEZ PEÑA AV. 200', 'price': '$ 200.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '30 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,74898', 'longitud': '-59,012367'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-espana-3-ambientes--16071370', 'address': 'AZOPARDO JUAN B. 1800', 'price': '$ 180.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '70 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,441233', 'longitud': '-59,016018'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-centenario-3-ambientes--16098191', 'address': 'ALEM LEANDRO N. 200', 'price': '$ 350.000', 'expensas': '+ $18.000 expensas', 'tipo': 'Departamento', 'superficie': '55 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,4604', 'longitud': '-58,991997'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16098223', 'address': 'AYACUCHO 100', 'price': '$ 300.000', 'expensas': '+ $18.000 expensas', 'tipo': 'Departamento', 'superficie': '35 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,448915', 'longitud': '-58,981865'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--16140470', 'address': 'VEDIA 100', 'price': '$ 350.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '65 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,45111', 'longitud': '-58,989655'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-santa-rita-3-ambientes--16143834', 'address': 'FOTHERINGHAM 2000', 'price': '$ 380.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '80 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,452488', 'longitud': '-59,021606'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-alta-2-ambientes--16143898', 'address': 'RAUL B DIAZ 300', 'price': '$ 220.000', 'expensas': '+ $18.000 expensas', 'tipo': 'Departamento', 'superficie': '40 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,437546', 'longitud': '-58,99653'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--16204446', 'address': 'AV LAS HERAS 500', 'price': '$ 260.000', 'expensas': '+ $18.000 expensas', 'tipo': 'Departamento', 'superficie': '50 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,46134', 'longitud': '-58,98416'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16204447', 'address': 'AYACUCHO 100', 'price': '$ 300.000', 'expensas': '+ $18.000 expensas', 'tipo': 'Departamento', 'superficie': '35 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,448915', 'longitud': '-58,981865'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-llaponagat-4-ambientes--16218604', 'address': 'PJE. ARTURO LESTANI 100', 'price': '$ 350.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '55 m² cubie.', 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '3 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,480268', 'longitud': '-58,97621'}
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-central-norte-1-ambiente--16220727', 'address': 'OBLIGADO 900', 'price': '$ 170.000', 'expensas': '+ $15.900 expensas', 'tipo': 'Departamento', 'superficie': '35 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,46096', 'longitud': '-58,980816'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-del-parque-2-ambientes--16139434', 'address': 'NECOCHEA 1200', 'price': '$ 140.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '32 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,458275', 'longitud': '-59,00007'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16244431', 'address': 'AV. RIVADAVIA 700', 'price': '$ 450.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '100 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,441223', 'longitud': '-58,98858'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--9387008', 'address': 'AV. ALVEAR 200', 'price': '$ 250.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '48 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,420132', 'longitud': '-59,035812'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-central-norte-1-ambiente--16272553', 'address': 'Avenida 9 Julio 1000', 'price': '$ 150.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '40 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,459541', 'longitud': '-58,977287'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-resistencia-4-ambientes--16276040', 'address': 'Donovan 700', 'price': '$ 330.000', 'expensas': '+ $77.000 expensas', 'tipo': 'Departamento', 'superficie': '54 m² cubie.', 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,453806', 'longitud': '-58,996452'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-alta-1-ambiente--16292884', 'address': 'roberto mora 200', 'price': '$ 200.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '32 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,439072', 'longitud': '-58,99601'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16298133', 'address': 'AV.ALVEAR 200', 'price': '$ 280.000', 'expensas': '+ $50.000 expensas', 'tipo': 'Departamento', 'superficie': '45 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,420132', 'longitud': '-59,035812'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--16300177', 'address': 'Avenida Alberdi 200', 'price': '$ 500.000', 'expensas': '+ $70.000 expensas', 'tipo': 'Departamento', 'superficie': '85 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,452965', 'longitud': '-58,988785'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-resistencia-2-ambientes--16306793', 'address': '2 DE FEBRERO 100', 'price': '$ 200.000', 'expensas': '+ $20.000 expensas', 'tipo': 'Departamento', 'superficie': '38 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,461487', 'longitud': '-59,002506'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-del-carmen-2-ambientes--16312456', 'address': 'NICOLAS R. ACOSTA 200', 'price': '$ 270.000', 'expensas': '+ $30.000 expensas', 'tipo': 'Departamento', 'superficie': '38 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,46207', 'longitud': '-58,97759'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--16319376', 'address': 'SARMIENTO AV. 500', 'price': '$ 350.000', 'expensas': '+ $130.000 expensas', 'tipo': 'Departamento', 'superficie': '50 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,446606', 'longitud': '-58,98171'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-2-ambientes--15313516', 'address': 'Cordoba 700', 'price': '$ 350.000', 'expensas': '+ $50.000 expensas', 'tipo': 'Departamento', 'superficie': '51 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,451601', 'longitud': '-58,973778'}
# No se encontró el precio de las expensas
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-macrocentro-1-ambiente--6581256', 'address': 'Cordoba 700, Piso 3', 'price': '$ 280.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '37 m² cubie.', 'cantidad_ambientes': 'Monoam.', 'cantidad_dormitorios': None, 'cantidad_banos': '1 baño', 'latitud': '-27,451546', 'longitud': '-58,973934'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-resistencia-3-ambientes--16334061', 'address': 'Vedia 300', 'price': '$ 380.000', 'expensas': '+ $100.000 expensas', 'tipo': 'Departamento', 'superficie': '50 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,452078', 'longitud': '-58,99142'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-4-ambientes--16347647', 'address': 'AVALOS 300', 'price': 'Consultar precio', 'expensas': '+ $220.000 expensas', 'tipo': 'Departamento', 'superficie': '200 m² cubie.', 'cantidad_ambientes': '4 ambientes', 'cantidad_dormitorios': '3 dorm.', 'cantidad_banos': '3 baños', 'latitud': '-27,442776', 'longitud': '-58,990894'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--16347658', 'address': 'SALTA 300', 'price': '$ 700.000', 'expensas': '+ $250.000 expensas', 'tipo': 'Departamento', 'superficie': '100 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,451162', 'longitud': '-58,991714'}
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-5-ambientes--15814437', 'address': '9 DE JULIO 300', 'price': '$ 450.000', 'expensas': '+ $110.000 expensas', 'tipo': 'Departamento', 'superficie': '115 m² cubie.', 'cantidad_ambientes': '5 ambientes', 'cantidad_dormitorios': '4 dorm.', 'cantidad_banos': '3 baños', 'latitud': '-27,45421', 'longitud': '-58,984207'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-llaponagat-3-ambientes--16361963', 'address': 'Av. Chaco 1100', 'price': '$ 350.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '62 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,47257', 'longitud': '-58,982048'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-villa-centenario-2-ambientes--6582167', 'address': 'ARBO Y BLANCO 1100, Piso P.B.', 'price': '$ 170.000', 'expensas': None, 'tipo': 'Departamento', 'superficie': '30 m² cubie.', 'cantidad_ambientes': '2 ambientes', 'cantidad_dormitorios': '1 dorm.', 'cantidad_banos': '1 baño', 'latitud': '-27,464682', 'longitud': '-58,99149'}
# No se encontró el precio de las expensas
# {'enlace': 'https://www.argenprop.com/departamento-en-alquiler-en-centro-3-ambientes--16373452', 'address': 'AV SARMIENTO 700', 'price': 'Consultar precio', 'expensas': None, 'tipo': 'Departamento', 'superficie': '80 m² cubie.', 'cantidad_ambientes': '3 ambientes', 'cantidad_dormitorios': '2 dorm.', 'cantidad_banos': '2 baños', 'latitud': '-27,445171', 'longitud': '-58,980213'}

# %%
#lista a data frame
df_argenpro = pd.DataFrame(data_argenprop)
df_argenpro.to_csv('departamentos_argenprop.csv', index=False)

# %% [markdown]
# segunda paguina web

# %%
#librerias 
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
import time

# %%
import re
def extraer_latitud_longitud(url):
    # Expresión regular para capturar la latitud y longitud
    patron = r"!3d(-?\d+\.\d+)!4d(-?\d+\.\d+)"
    coincidencia = re.search(patron, url)
    
    if coincidencia:
        latitud = float(coincidencia.group(1))
        longitud = float(coincidencia.group(2))
        return latitud, longitud
    else:
        return None

# %%
# Abrir el navegador Edge
driver = webdriver.Edge()

links=[]

try:
    # Página web
    url = 'https://www.zonaprop.com.ar/casas-departamentos-ph-alquiler-resistencia.html'

    # Abrir la página
    driver.get(url)

    # Obtener el elemento entre pagination__separator y pagination__page-next
    try:
        texto_con_cantidad = driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/div/div/div[2]/div[2]/div[1]/div/div[1]/h1').text
    except NoSuchElementException:
        print("No se encontró el texto con la cantidad de departamentos")
    # extraer el texto con la cantidad de departamentos dejando solo los numeros
    numero_despartamentos = int(''.join(filter(str.isdigit, texto_con_cantidad)))

    numero_paginas = int(np.ceil(numero_despartamentos / 30))

    print(f"Numero de paginas: {numero_paginas}")



    for i in range(1, numero_paginas + 1):
        print(f"Página {i}")
        
        # Obtener el div que contiene los departamentos
        try:
            departamentos_div = driver.find_element(By.XPATH, '//div[@class="postings-container"]')
        except NoSuchElementException:
            print("No se encontró el div que contiene los departamentos")
            continue
        
        # Obtener los departamentos usando un XPath relativo
        departamentos = departamentos_div.find_elements(By.XPATH, './div')
        print(f"Número de departamentos: {len(departamentos)}")
        
        for f in range(len(departamentos)):
            print(f"Departamento {f+1}")
            try:
                enlaces = departamentos[f].find_elements(By.XPATH, './/a')
                for enlace in enlaces:
                    href = enlace.get_attribute('href')
                    print(f"Href: {href}")
                    links.append(href)
            except NoSuchElementException:
                print(f"No se encontró el enlace en el departamento {f+1}")

        # Cambiar de página
        if i < numero_paginas:
            try:
                siguiente = driver.find_element(By.XPATH, '//a[@class="PageArrow-sc-n5babu-2 kTvCSV"]')
                siguiente_href = siguiente.get_attribute('href')
                driver.get(siguiente_href)
                time.sleep(3)  # Esperar un momento para que la página cargue
            except NoSuchElementException:
                print("No se encontró el botón de siguiente página")
                break
                
        wait = WebDriverWait(driver, 10)

finally:
    # Cerrar el navegador
    driver.quit()
    print("fin")
# Out:
# No se encontró el texto con la cantidad de departamentos
# Numero de paginas: 2
# Página 1
# Número de departamentos: 30
# Departamento 1
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin--monoambiente-en-alquiler!-necochea-858-resistencia-54744215.html
# Departamento 2
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-se-alquila-departamento-un-dormitorio-frente-zona-54694102.html
# Departamento 3
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin--departamento-en-alquiler!-los-hacheros-55-54743755.html
# Departamento 4
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclcain-casa-en-alquiler-excelente-ubicacion-54730734.html
# Departamento 5
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-departamento-1-ambiente-villa-central-norte-54515761.html
# Departamento 6
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-departamento-3-ambientes-centro-resistencia-54741627.html
# Departamento 7
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-departamento-2-habitaciones-con-cochera-54316559.html
# Departamento 8
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclcain-departamento-un-dormitorio-con-cochera-54709996.html
# Departamento 9
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-departamento-1-ambiente-macrocentro-resistencia-44797336.html
# Departamento 10
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-alquiler-3-dorm.-brown-139-microcentro-54709808.html
# Departamento 11
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-leandro-alem-1615-dpto-1-dormitorio-54637018.html
# Departamento 12
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclcain-casas-duplex-macrocentro-resistencia-48435901.html
# Departamento 13
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclcain-alquiler-casa-destino-exclusivo-comercial-54519033.html
# Departamento 14
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-departamento-en-alquiler-54629745.html
# Departamento 15
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclcain-casa-en-alquiler-la-liguria-54658343.html
# Departamento 16
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-financia-en-cuotas-sin-interes-los-honorarios-31817043.html
# Departamento 17
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-departamento-2-ambientes-macrocentro-resistencia-54256095.html
# Departamento 18
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-financia-en-cuotas-sin-interes-los-honorarios-26680005.html
# Departamento 19
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclcain-solo-apto-para-destino-comercial-53238187.html
# Departamento 20
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-departamento-a-esternar-2-dorm.-av-piacentini-1331-54745764.html
# Departamento 21
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclcain-casa-3-dorm.-con-cochera-doble-ricardo-rojas-535-54671892.html
# Departamento 22
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-financia-en-cuotas-sin-interes-los-honorarios-41628210.html
# Departamento 23
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-departamento-monoambiente-pb-en-arbo-y-blanco-1399.-54722633.html
# Departamento 24
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-financia-en-cuotas-sin-interes-los-honorarios-30589284.html
# Departamento 25
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-financia-en-cuotas-sin-interes-los-honorarios-33119601.html
# Departamento 26
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-departamento-2-ambientes-centro-resistencia-53033883.html
# Departamento 27
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-financia-en-cuotas-sin-interes-los-honorarios-23646656.html
# Departamento 28
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-financia-en-cuotas-sin-interes-los-honorarios-47077576.html
# Departamento 29
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-alquiler-departamento-2-dorm.-macrocentro-54589240.html
# Departamento 30
# Href: https://www.zonaprop.com.ar/propiedades/clasificado/alclapin-financia-en-cuotas-sin-interes-los-honorarios-28387449.html
# Página 2
# No se encontró el div que contiene los departamentos
# fin

# %% [markdown]
# este lo dejo para mas adelante porque tiene un capcha

# %% [markdown]
# pasao a las siguiente inmobiliaria

# %%
#librerias 
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
import time

# %%
# Abrir el navegador Edge
driver = webdriver.Edge()

links=[]

try:
    # Página web
    url = 'http://www.estudioorcola.com/listado.php?modalidad=1&categoria=4#inicioLista'

    # Abrir la página
    driver.get(url)
        # Obtener el div que contiene los departamentos
    try:
        departamentos_div = driver.find_element(By.XPATH, '/html/body/div[5]')
    except NoSuchElementException:
        print("No se encontró el div que contiene los departamentos")
    
        
        # Obtener los departamentos usando un XPath relativo
    departamentos = departamentos_div.find_elements(By.XPATH, './a')
    print(f"Número de departamentos: {len(departamentos)}")
        
    for f in range(len(departamentos)):
        print(f"Departamento {f+1}")
        try:
            enlace = departamentos[f]
            href = enlace.get_attribute('href')
            print(f"Href: {href}")
            links.append(href)
        except NoSuchElementException:
            print(f"No se encontró el enlace en el departamento {f+1}")

        # Cambiar de página
    if i < numero_paginas:
        try:
            siguiente = driver.find_element(By.XPATH, '//a[@class="PageArrow-sc-n5babu-2 kTvCSV"]')
            siguiente_href = siguiente.get_attribute('href')
            driver.get(siguiente_href)
            time.sleep(3)  # Esperar un momento para que la página cargue
        except NoSuchElementException:
            print("No se encontró el botón de siguiente página")
            
                

finally:
    # Cerrar el navegador
    #driver.quit()
    print("fin")
# Out:
# Número de departamentos: 13
# Departamento 1
# Href: https://www.estudioorcola.com/ficha.php?codigo=19111202&modalidad=1
# Departamento 2
# Href: https://www.estudioorcola.com/ficha.php?codigo=219622&modalidad=1
# Departamento 3
# Href: https://www.estudioorcola.com/ficha.php?codigo=249450&modalidad=1
# Departamento 4
# Href: https://www.estudioorcola.com/ficha.php?codigo=2492645&modalidad=1
# Departamento 5
# Href: https://www.estudioorcola.com/ficha.php?codigo=2492603&modalidad=1
# Departamento 6
# Href: https://www.estudioorcola.com/ficha.php?codigo=2492620&modalidad=1
# Departamento 7
# Href: https://www.estudioorcola.com/ficha.php?codigo=2212327&modalidad=1
# Departamento 8
# Href: https://www.estudioorcola.com/ficha.php?codigo=1353049&modalidad=1
# Departamento 9
# Href: https://www.estudioorcola.com/ficha.php?codigo=22111936&modalidad=1
# Departamento 10
# Href: https://www.estudioorcola.com/ficha.php?codigo=249911&modalidad=1
# Departamento 11
# Href: https://www.estudioorcola.com/ficha.php?codigo=249459&modalidad=1
# Departamento 12
# Href: https://www.estudioorcola.com/ficha.php?codigo=1842446&modalidad=1
# Departamento 13
# Href: https://www.estudioorcola.com/ficha.php?codigo=242555&modalidad=1
# fin

# %%
import re

def obtener_latitud(url):
    # Expresión regular para capturar la latitud
    patron_latitud = r"!3d(-?\d+\.\d+)"
    coincidencia_latitud = re.search(patron_latitud, url)
    
    if coincidencia_latitud:
        latitud = float(coincidencia_latitud.group(1))
        return latitud
    else:
        return None

def obtener_longitud(url):
    # Expresión regular para capturar la longitud
    patron_longitud = r"!2d(-?\d+\.\d+)"
    coincidencia_longitud = re.search(patron_longitud, url)
    
    if coincidencia_longitud:
        longitud = float(coincidencia_longitud.group(1))
        return longitud
    else:
        return None

# %%
#iterar sobre los enlaces guardados en la lista links

data_orcola = []
driver = webdriver.Edge()

try:
    for enlace in links:
        bandera = True

        driver.get(enlace)
        time.sleep(3)  # Esperar un momento para que la página cargue
        
        # Obtener la información del departamento
        try:
            address = driver.find_element(By.XPATH, '//div[@class="fichaDireccion"]').text
        except NoSuchElementException:
            print("No se encontró la direccion")
            address = None
        
        try:
            price = driver.find_element(By.XPATH, '//p[@class="text-center fichaSimplificadaPrecio"]').text
        except NoSuchElementException:
            print("No se encontró el precio")
            price = None

        try:
            expensas = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[1]/div[1]/div[2]/p').text
        except NoSuchElementException:
            print("No se encontró el precio de las expensas")
            expensas = None

        try:
            descripcion = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[1]/div[1]/div[2]/div[2]/p').text
        except NoSuchElementException:
            print("No se encontró la descripción")
            descripcion = None
        
        try:
            tipo = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[1]/div[1]/div[2]/div[2]/ul/li[1]').text
        except NoSuchElementException:
            print("No se encontró el tipo")
            tipo = None

        try:
            superficie = driver.find_element(By.XPATH, '/html/body/div[4]/div[4]/div/div[3]/h1').text
        except NoSuchElementException:
            print("No se encontró la superficie")
            superficie = None
        
        try:
            cantidad_ambientes = driver.find_element(By.XPATH, '/html/body/div[4]/div[4]/div/div[1]/h1').text

        except NoSuchElementException:
            print("No se encontró la cantidad de ambientes")
            cantidad_ambientes = None

        try:
            cantidad_dormitorios = driver.find_element(By.XPATH, '/html/body/div[5]/div[1]/div[1]/div[1]/div[2]/div[2]/ul/li[4]').text
        except NoSuchElementException:
            print("No se encontró la cantidad de dormitorios")
            cantidad_dormitorios = None

        try:
            cantidad_banos = driver.find_element(By.XPATH, '/html/body/div[4]/div[4]/div/div[2]/h1').text
        except NoSuchElementException:
            print("No se encontró la cantidad de baños")
            cantidad_banos = None

        try:
            # obtener div de mapa de google map
            mapa = driver.find_element(By.XPATH, '//*[@id="mapas"]/div/div[1]/iframe')
        except NoSuchElementException:
            print("No se encontró el mapa")
            bandera = False


        #obtener latitud y longitud de los atributos del div

        try:
            if mapa is bandera:
                url = mapa.get_attribute('src')
                print(f"Latitud y longitud en URL: {url}")
                latitud = obtener_latitud(url)
                longitud = obtener_longitud(url)
            else:
                latitud = None
                longitud = None
        except NoSuchElementException:
            print("No se encontró el mapa")
            latitud = None
            longitud = None
        except TypeError:
            print("No se pudo extraer la latitud y longitud")
            latitud = None
            longitud = None

            
        departamento_info = {
            "enlace": enlace,
            "address": address,
            "price": price,
            "expensas": expensas,
            "tipo": tipo,
            "superficie": superficie,
            "cantidad_ambientes": cantidad_ambientes,
            "cantidad_dormitorios": cantidad_dormitorios,
            "cantidad_banos": cantidad_banos,
            "latitud": latitud,
            "longitud": longitud
        }

        data_orcola.append(departamento_info)

        print(departamento_info)


finally:
    driver.quit()
    print("fin")
# Out:
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=19111202&modalidad=1', 'address': 'Avenida Rivadavia 810 - Macrocentro', 'price': '$ 430.000', 'expensas': None, 'tipo': None, 'superficie': '50', 'cantidad_ambientes': '2', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=219622&modalidad=1', 'address': 'Las Heras 766 - U.N.N.E.', 'price': '$ 290.000', 'expensas': None, 'tipo': None, 'superficie': '36', 'cantidad_ambientes': 'Mono', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=249450&modalidad=1', 'address': 'Franklin 756 - Zona Unne', 'price': '230.000', 'expensas': None, 'tipo': None, 'superficie': '35', 'cantidad_ambientes': 'MONO', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=2492645&modalidad=1', 'address': 'Avenida Wilde 12 - Micro Centro', 'price': '$ 400.000', 'expensas': None, 'tipo': None, 'superficie': '-', 'cantidad_ambientes': '2', 'cantidad_dormitorios': None, 'cantidad_banos': '2', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=2492603&modalidad=1', 'address': 'San Lorenzo 1180 - Zona Unne', 'price': '$ 200.000', 'expensas': None, 'tipo': None, 'superficie': '-', 'cantidad_ambientes': '1', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=2492620&modalidad=1', 'address': 'Pueyrredon 455 - Micro Centro', 'price': '$ 380.000', 'expensas': None, 'tipo': None, 'superficie': '-', 'cantidad_ambientes': '2', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=2212327&modalidad=1', 'address': 'Avenida Sarmiento 764 - Macrocentro', 'price': '$ 280.000', 'expensas': None, 'tipo': None, 'superficie': '40', 'cantidad_ambientes': 'Mono', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=1353049&modalidad=1', 'address': 'Frondizi 850 - Macrocentro', 'price': '$ 270.000', 'expensas': None, 'tipo': None, 'superficie': '65', 'cantidad_ambientes': '2', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# No se encontró el mapa
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=22111936&modalidad=1', 'address': 'Av. Sarmiento 440 - Macrocentro', 'price': '$ 400.000', 'expensas': None, 'tipo': None, 'superficie': '86', 'cantidad_ambientes': '2', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=249911&modalidad=1', 'address': 'Alem 495 - -', 'price': '$ 200.000', 'expensas': None, 'tipo': None, 'superficie': '35', 'cantidad_ambientes': '1', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=249459&modalidad=1', 'address': 'Roberto Mora 60 - Macro Centro', 'price': '$ 230.000', 'expensas': None, 'tipo': None, 'superficie': '38', 'cantidad_ambientes': '1', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=1842446&modalidad=1', 'address': 'Ameghino 935 - UNNE', 'price': '$ 35.000', 'expensas': None, 'tipo': None, 'superficie': '98', 'cantidad_ambientes': '3', 'cantidad_dormitorios': None, 'cantidad_banos': '2', 'latitud': None, 'longitud': None}
# No se encontró el precio de las expensas
# No se encontró la descripción
# No se encontró el tipo
# No se encontró la cantidad de dormitorios
# {'enlace': 'https://www.estudioorcola.com/ficha.php?codigo=242555&modalidad=1', 'address': 'Maipu 763 (CABA) - Galerias Pacifico (ALQUILER TEMPORARIO)', 'price': 'Consultar Precio', 'expensas': None, 'tipo': None, 'superficie': '38', 'cantidad_ambientes': 'Mono', 'cantidad_dormitorios': None, 'cantidad_banos': '1', 'latitud': None, 'longitud': None}
# fin

# %%
#lista a data frame
df_orcola = pd.DataFrame(data_orcola)
df_orcola.to_csv('departamentos_orcola.csv', index=False)

# %% [markdown]
# siguiente paguina

# %%
# Abrir el navegador Edge
driver = webdriver.Edge()

links=[]

try:
    # Página web
    url = 'https://www.amudpropiedades.com/propiedades.aspx?d=1&operacion=Alquiler&producto=Departamentos&pais=Argentina&provincia=CHACO'

    # Abrir la página
    driver.get(url)
    '''
    # Obtener el elemento entre pagination__separator y pagination__page-next
    try:
        texto_con_cantidad = driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/div/div/div[2]/div[2]/div[1]/div/div[1]/h1').text
    except NoSuchElementException:
        print("No se encontró el texto con la cantidad de departamentos")
    # extraer el texto con la cantidad de departamentos dejando solo los numeros
    numero_despartamentos = int(''.join(filter(str.isdigit, texto_con_cantidad)))

    numero_paginas = int(np.ceil(numero_despartamentos / 30))

    print(f"Numero de paginas: {numero_paginas}")



    for i in range(1, numero_paginas + 1):
        print(f"Página {i}")
        
        # Obtener el div que contiene los departamentos
        try:
            departamentos_div = driver.find_element(By.XPATH, '//div[@class="postings-container"]')
        except NoSuchElementException:
            print("No se encontró el div que contiene los departamentos")
            continue
        
        # Obtener los departamentos usando un XPath relativo
        departamentos = departamentos_div.find_elements(By.XPATH, './div')
        print(f"Número de departamentos: {len(departamentos)}")
        
        for f in range(len(departamentos)):
            print(f"Departamento {f+1}")
            try:
                enlaces = departamentos[f].find_elements(By.XPATH, './/a')
                for enlace in enlaces:
                    href = enlace.get_attribute('href')
                    print(f"Href: {href}")
                    links.append(href)
            except NoSuchElementException:
                print(f"No se encontró el enlace en el departamento {f+1}")

        # Cambiar de página
        if i < numero_paginas:
            try:
                siguiente = driver.find_element(By.XPATH, '//a[@class="PageArrow-sc-n5babu-2 kTvCSV"]')
                siguiente_href = siguiente.get_attribute('href')
                driver.get(siguiente_href)
                time.sleep(3)  # Esperar un momento para que la página cargue
            except NoSuchElementException:
                print("No se encontró el botón de siguiente página")
                break
                
        '''

finally:
    # Cerrar el navegador
    driver.quit()
    print("fin")
